# %%
import os

import folium
from folium import Map, Marker, LayerControl
#from folium.plugins import MarkerCluster
from folium.plugins import BeautifyIcon
import json


import fiona as fn
import shapely
from shapely import geometry
from shapely.geometry import shape, Polygon, mapping, MultiPolygon, LineString, Point
from shapely.ops import cascaded_union, transform
import pandas as pd

import openrouteservice as ors

from openrouteservice import client

from openrouteservice import convert

import pyproj

import pandas as pd
import geopandas as gpd

#----






token = "5b3ce3597851110001cf6248d572cfb59518430f8d918cfbcd904505"
sites_csv = "./pts.csv"

incidents_json = "./incidents.json"

depot = [-12.195997, -77.01355]

# %%
deliveries_data = pd.read_csv(sites_csv, index_col="index")
deliveries_data.head()
# Out:
#              lon        lat
# index
# 0     -77.013559 -12.195996
# 1     -76.997766 -12.191298
# 2     -76.988325 -12.164031
# 3     -76.993475 -12.162436
# 4     -76.978025 -12.192305

# %%
# Define the vehicles
# https://openrouteservice-py.readthedocs.io/en/latest/openrouteservice.html#openrouteservice.optimization.Vehicle
vehicles = list()
for idx in range(3):
    vehicles.append(
        ors.optimization.Vehicle(
            id=idx, 
            start=list(reversed(depot)),
            end=list(reversed(depot)),
            capacity=[900],
            #time_window=[1553241600, 1553284800]  # Fri 8-20:00, expressed in POSIX timestamp
        )
    )
    
# Next define the delivery stations
# https://openrouteservice-py.readthedocs.io/en/latest/openrouteservice.html#openrouteservice.optimization.Job
deliveries = list()
for delivery in deliveries_data.itertuples():
    deliveries.append(
        ors.optimization.Job(
            id=delivery.Index,
            location=[delivery.lon, delivery.lat],
            service=1200,  # Assume 20 minutes at each site
            amount=[300],
            #time_windows=[[
            #    int(delivery.Open_From.timestamp()),  # VROOM expects UNIX timestamp
            #    int(delivery.Open_To.timestamp())
            #]]
        )
    )

# %%
# Initialize a client and make the request
ors_client = ors.Client(key=token)  # Get an API key from https://openrouteservice.org/dev/#/signup
opt_result = ors_client.optimization(
    jobs=deliveries,
    vehicles=vehicles,
    geometry=True
)
for idx, rt in enumerate(opt_result['routes']):
    #geometry = ors.convert.decode_polyline(rt['geometry'])
    opt_result['routes'][idx]['geometry'] = ors.convert.decode_polyline(rt['geometry'])

# %%
# Make a map!

# First define the map centered around Beira
m = folium.Map(location=depot, tiles='OpenStreetMap', zoom_start=12)    


# Plot the locations on the map with more info in the ToolTip
for location in deliveries_data.itertuples():
    #tooltip = folium.map.Tooltip("<h4><b>ID {}</b></p><p>Supplies needed: <b>{}</b></p>".format(
    #    location.Index, location.Needed_Amount
    #))
    
    folium.Marker(
        location=[location.lat, location.lon],
        #tooltip=tooltip,
        icon=BeautifyIcon(
            icon_shape='marker',
            #number=int(location.index),
            spin=True,
            text_color='red',
            background_color="#FFF",
            inner_icon_style="font-size:12px;padding-top:-5px;"
        )
    #)
    ).add_to(m)    
    
# The vehicles are all located at the port of Beira
#depot = [-19.818474, 34.835447]

folium.Marker(
    location=depot,
    icon=BeautifyIcon(
            icon_shape='marker',
            #number=int(location.index),
            spin=True,
            text_color='green',
            background_color="pink",
            inner_icon_style="font-size:12px;padding-top:-5px;"
        ),
    setZIndexOffset=1000
).add_to(m)


# Add the output to the map
for color, route in zip(['green', 'red', 'blue'], opt_result['routes']):
    
    #decoded=ors.convert.decode_polyline(route['geometry'])  # Route geometry is encoded
    #print(decoded)
    
       
    gj = folium.GeoJson(
        name='Vehicle {}'.format(route['vehicle']),
        data={"type": "FeatureCollection", "features": [{"type": "Feature", 
                                                         "geometry": route['geometry'],
                                                         "properties": {"color": color}
                                                        }]},
        style_function=lambda x: {"color": x['properties']['color']}
    )
    gj.add_child(folium.Tooltip(
        """<h4>Vehicle {vehicle}</h4>
        <b>Distance</b> {distance} m <br>
        <b>Duration</b> {duration} secs
        """.format(**route)
    ))

    gj.add_to(m)
    
i2 = folium.features.GeoJson(open(incidents_json).read())
i2.add_to(m)


folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
opt_result
# Out:
# {'code': 0,
#  'summary': {'cost': 4943,
#   'unassigned': 0,
#   'amount': [2700],
#   'service': 10800,
#   'duration': 4943,
#   'waiting_time': 0,
#   'distance': 48451,
#   'computing_times': {'loading': 79, 'solving': 5, 'routing': 112}},
#  'unassigned': [],
#  'routes': [{'vehicle': 0,
#    'cost': 1473,
#    'amount': [900],
#    'service': 3600,
#    'duration': 1473,
#    'waiting_time': 0,
#    'distance': 12361,
#    'steps': [{'type': 'start',
#      'location': [-77.01355, -12.195997],
#      'arrival': 0,
#      'duration': 0,
#      'distance': 0},
#     {'type': 'job',
#      'location': [-76.98832511901854, -12.164030528025286],
#      'job': 2,
#      'service': 1200,
#      'waiting_time': 0,
#      'arrival': 620,
#      'duration': 620,
#      'distance': 5619},
#     {'type': 'job',
#      'location': [-76.99347496032716, -12.162436353905024],
#      'job': 3,
#      'service': 1200,
#      'waiting_time': 0,
#      'arrival': 2052,
#      'duration': 852,
#      'distance': 6567},
#     {'type': 'job',
#      'location': [-77.01355934143065, -12.195995894651212],
#      'job': 0,
#      'service': 1200,
#      'waiting_time': 0,
#      'arrival': 3873,
#      'duration': 1473,
#      'distance': 12360},
#     {'type': 'end',
#      'location': [-77.01355, -12.195997],
#      'arrival': 5073,
#      'duration': 1473,
#      'distance': 12361}],
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-77.01364, -12.19614],
#      [-77.01337, -12.1963],
#      [-77.01247, -12.19684],
#      [-77.01187, -12.19601],
#      [-77.01181, -12.19598],
#      [-77.01086, -12.19654],
#      [-77.01096, -12.19668],
#      [-77.01085, -12.19676],
#      [-77.01075, -12.19662],
#      [-77.01065, -12.19648],
#      [-77.01055, -12.19634],
#      [-77.01032, -12.19603],
#      [-77.0102, -12.19575],
#      [-77.00972, -12.19504],
#      [-77.0097, -12.195],
#      [-77.00902, -12.19407],
#      [-77.00897, -12.194],
#      [-77.00814, -12.19284],
#      [-77.0081, -12.19278],
#      [-77.00805, -12.19272],
#      [-77.00705, -12.19135],
#      [-77.00665, -12.19077],
#      [-77.00636, -12.19036],
#      [-77.00632, -12.1903],
#      [-77.00623, -12.19019],
#      [-77.00628, -12.19014],
#      [-77.00653, -12.1899],
#      [-77.00682, -12.1896],
#      [-76.98801, -12.19336],
#      [-76.9882, -12.1932],
#      [-76.98857, -12.19287],
#      [-76.98866, -12.19282],
#      [-76.98885, -12.19269],
#      [-76.98913, -12.1925],
#      [-76.9896, -12.19216],
#      [-76.98966, -12.19212],
#      [-76.99006, -12.1918],
#      [-76.99048, -12.19143],
#      [-76.99109, -12.19213],
#      [-76.99183, -12.19298],
#      [-76.99249, -12.19371],
#      [-76.9932, -12.1931],
#      [-76.99392, -12.1924],
#      [-76.99461, -12.19314],
#      [-76.99535, -12.19244],
#      [-76.99609, -12.19173],
#      [-76.99685, -12.19103],
#      [-76.99758, -12.19179],
#      [-76.99792, -12.19145],
#      [-76.99815, -12.19123],
#      [-76.99831, -12.19106],
#      [-76.99909, -12.19184],
#      [-76.99874, -12.19217],
#      [-76.99923, -12.19265],
#      [-76.99942, -12.19292],
#      [-76.99966, -12.19331],
#      [-76.99983, -12.19367],
#      [-76.99994, -12.19399],
#      [-76.99995, -12.19417],
#      [-76.99987, -12.19496],
#      [-77.00017, -12.19502],
#      [-77.00065, -12.19513],
#      [-77.00116, -12.19526],
#      [-77.00127, -12.19529],
#      [-77.00146, -12.19509],
#      [-77.00173, -12.19481],
#      [-77.0018, -12.19474],
#      [-77.00253, -12.194],
#      [-77.00262, -12.1939],
#      [-77.00267, -12.19385],
#      [-77.00275, -12.19377],
#      [-77.0034, -12.19311],
#      [-77.00373, -12.19277],
#      [-77.00469, -12.19178],
#      [-77.00588, -12.19055],
#      [-77.00599, -12.19042],
#      [-77.00623, -12.19019],
#      [-77.00628, -12.19014],
#      [-77.00638, -12.19025],
#      [-77.00776, -12.19218],
#      [-77.00812, -12.19268],
#      [-77.00816, -12.19273],
#      [-77.0082, -12.19279],
#      [-77.00903, -12.19395],
#      [-77.00908, -12.19402],
#      [-77.00969, -12.19487],
#      [-77.01033, -12.19578],
#      [-77.01043, -12.19596],
#      [-77.01086, -12.19654],
#      [-77.01096, -12.19668],
#      [-77.01105, -12.19681],
#      [-77.01134, -12.1972],
#      [-77.0115, -12.19743],
#      [-77.01187, -12.19721],
#      [-77.01216, -12.19703],
#      [-77.01247, -12.19684],
#      [-77.01337, -12.1963],
#      [-77.01364, -12.19614]]}}]}

# %%
# Reshape opt_result to fit the response pattern:
response = { 
    "steps": {
        "type": "FeatureCollection",
        "features": []
    }, 
    "routes": {
        "type": "FeatureCollection",
        "features": []
    } 
}
for idx, rt in enumerate(opt_result['routes']):
    vehicle = rt['vehicle']
    
    # Put routes in:
    response['routes']['features'].append({
        "type":"Feature",
        "properties":{
           "distance": rt['distance'],
           "duration": rt['duration'],
           "vehicle": vehicle,
           "recalculated": "false"
        },
        "geometry": rt['geometry']
     })
    
    # Put steps in:
    for step in rt['steps']:
        if step['type'] == 'start':
            job = 99999
        elif step['type'] == 'end':
            job = -1
        else:
            job = step['job']
            
        response['steps']['features'].append({    
            "type":"Feature",
            "properties":{
               "type": step['type'],
               "job": job,
               "vehicle": vehicle
            },
            "geometry":{
               "type":"Point",
               "coordinates": step['location']
            }
        })

#response = json.dumps(response)
response
# Out:
# {'steps': {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'type': 'start', 'job': 99999, 'vehicle': 0},
#     'geometry': {'type': 'Point', 'coordinates': [-77.01355, -12.195997]}},
#    {'type': 'Feature',
#     'properties': {'type': 'job', 'job': 2, 'vehicle': 0},
#     'geometry': {'type': 'Point',
#      'coordinates': [-76.98832511901854, -12.164030528025286]}},
#    {'type': 'Feature',
#     'properties': {'type': 'job', 'job': 3, 'vehicle': 0},
#     'geometry': {'type': 'Point',
#      'coordinates': [-76.99347496032716, -12.162436353905024]}},
#    {'type': 'Feature',
#     'properties': {'type': 'job', 'job': 0, 'vehicle': 0},
#     'geometry': {'type': 'Point',
#      'coordinates': [-77.01355934143065, -12.195995894651212]}},
#    {'type': 'Feature',
#     'properties': {'type': 'end', 'job': -1, 'vehicle': 0},
#     'geometry': {'type': 'Point', 'coordinates': [-77.01355, -12.195997]}},
#    {'type': 'Feature',
#     'properties': {'type': 'start', 'job': 99999, 'vehicle': 1},
#     'geometry': {'type': 'Point', 'coordinates': [-77.01355, -12.195997]}},
#    {'type': 'Feature',
#     'properties': {'type': 'job', 'job': 8, 'vehicle': 1},
#     'geometry': {'type': 'Point',
#      'coordinates': [-76.97227478027344, -12.138690418934832]}},
#    {'type': 'Feature',
#     'properties': {'type': 'job', 'job': 7, 'vehicle': 1},
#     'geometry': {'type': 'Point',
#      'coordinates': [-76.96523666381835, -12.158157207685294]}},
#    {'type': 'Feature',
#     'properties': {'type': 'job', 'job': 6, 'vehicle': 1},
#     'geometry': {'type': 'Point',
#      'coordinates': [-76.97133064270021, -12.167722262962966]}},
#    {'type': 'Feature',
#     'properties': {'type': 'end', 'job': -1, 'vehicle': 1},
#     'geometry': {'type': 'Point', 'coordinates': [-77.01355, -12.195997]}},
#    {'type': 'Feature',
#     'properties': {'type': 'start', 'job': 99999, 'vehicle': 2},
#     'geometry': {'type': 'Point', 'coordinates': [-77.01355, -12.195997]}},
#    {'type': 'Feature',
#     'properties': {'type': 'job', 'job': 4, 'vehicle': 2},
#     'geometry': {'type': 'Point',
#      'coordinates': [-76.97802543640138, -12.192304552907098]}},
#    {'type': 'Feature',
#     'properties': {'type': 'job', 'job': 5, 'vehicle': 2},
#     'geometry': {'type': 'Point',
#      'coordinates': [-76.98266029357909, -12.1997710773601]}},
#    {'type': 'Feature',
#     'properties': {'type': 'job', 'job': 1, 'vehicle': 2},
#     'geometry': {'type': 'Point',
#      'coordinates': [-76.99776649475099, -12.191297814421771]}},
#    {'type': 'Feature',
#     'properties': {'type': 'end', 'job': -1, 'vehicle': 2},
#     'geometry': {'type': 'Point', 'coordinates': [-77.01355, -12.195997]}}]},
#  'routes': {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'distance': 12361,
#      'duration': 1473,
#      'vehicle': 0,
#      'recalculated': 'false'},
#     'geometry': {'type': 'LineString',
#      'coordinates': [[-77.01364, -12.19614],
#       [-77.01337, -12.1963],
#       [-77.01247, -12.19684],
#       [-77.01187, -12.19601],
#       [-77.01181, -12.19598],
#       [-77.01086, -12.19654],
#       [-77.01096, -12.19668],
#       [-77.01085, -12.19676],
#       [-77.01075, -12.19662],
#       [-77.01065, -12.19648],
#       [-77.01055, -12.19634],
#       [-77.01032, -12.19603],
#       [-77.0102, -12.19575],
#       [-77.00972, -12.19504],
#       [-77.0097, -12.195],
#       [-77.00902, -12.19407],
#       [-77.00897, -12.194],
#       [-77.00275, -12.19377],
#       [-77.0034, -12.19311],
#       [-77.00373, -12.19277],
#       [-77.00469, -12.19178],
#       [-77.00588, -12.19055],
#       [-77.00599, -12.19042],
#       [-77.00623, -12.19019],
#       [-77.00628, -12.19014],
#       [-77.00638, -12.19025],
#       [-77.00776, -12.19218],
#       [-77.00812, -12.19268],
#       [-77.00816, -12.19273],
#       [-77.0082, -12.19279],
#       [-77.00903, -12.19395],
#       [-77.00908, -12.19402],
#       [-77.00969, -12.19487],
#       [-77.01033, -12.19578],
#       [-77.01043, -12.19596],
#       [-77.01086, -12.19654],
#       [-77.01096, -12.19668],
#       [-77.01105, -12.19681],
#       [-77.01134, -12.1972],
#       [-77.0115, -12.19743],
#       [-77.01187, -12.19721],
#       [-77.01216, -12.19703],
#       [-77.01247, -12.19684],
#       [-77.01337, -12.1963],
#       [-77.01364, -12.19614]]}}]}}

# %%
rts = gpd.GeoDataFrame.from_features(response['routes']['features'])
rts.crs = {'init' :'epsg:4326'}

# %%
# Load geojson with incidents
#ncidents_file = "https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/antarctic_ice_edge.json"
incidents = gpd.read_file("./incidents.json")
incidents.crs = {'init' :'epsg:4326'}

# %%
incidents_gj = incidents.__geo_interface__

# %%
list(incidents['geometry'])
# Out:
# [<shapely.geometry.polygon.Polygon at 0x11aca1210>,
#  <shapely.geometry.polygon.Polygon at 0x11aca1290>,
#  <shapely.geometry.polygon.Polygon at 0x11aca14d0>]

# %%
# Compute Intersections
crosses = gpd.sjoin(incidents, rts, how='left', op='intersects', lsuffix='left', rsuffix='right')
bad_rts = pd.unique(crosses['vehicle'])
bad_rts
crosses.head()
# Out:
#     stroke  stroke-width  stroke-opacity     fill  fill-opacity  \
# 0  #555555             2               1  #555555           0.5
# 1  #555555             2               1  #555555           0.5
# 2  #555555             2               1  #555555           0.5
#
#         incident                                           geometry  \
# 0     flood_zone  POLYGON ((-76.96862697601318 -12.1659603049577...
# 1  zombie_attack  POLYGON ((-76.99416160583495 -12.1957651872979...
# 2     flood_zone  POLYGON ((-76.98965549468994 -12.1925142896104...
#
#    index_right  distance  duration  vehicle recalculated
# 0            1     23864      2213        1        false
# 1            2     12226      1257        2        false
# 2            2     12226      1257        2        false

# %%
# Now we know that we have to recalculate the route for vehicles that cross an issue area
# Go through the routes to find which ones we need to recalculate:
for idx, rt in enumerate(response['routes']['features']):
    vehicle = rt['properties']['vehicle']
    if vehicle in bad_rts:
        print("{} has bad route".format(vehicle))
        # Get start and end:
        coords_list = []
        
        for st in response['steps']['features']:
            if st['properties']['vehicle'] == vehicle:
                coords = st['geometry']['coordinates']
                
                if st['properties']['type'] == 'start':
                    start_coords = coords
                elif st['properties']['type'] == 'end':
                    end_coords = coords
                else:
                    coords_list.insert(st['properties']['job'], coords)
        
        coords_list.insert(0, start_coords)
        coords_list.append(end_coords)
        #print(coords_list)
        route_request = {
            'coordinates': coords_list, 
            'format_out': 'geojson',
            'profile': 'driving-car',
            #'preference': 'shortest',
            #'optimize_waypoints': True,
            'instructions': False,
            'options': {'avoid_polygons': geometry.mapping(MultiPolygon(list(incidents['geometry'])))} 
        }         
        route_directions = ors_client.directions(**route_request)
        #print(route_directions)
        response['routes']['features'][idx]['geometry'] = route_directions['features'][0]['geometry']
        response['routes']['features'][idx]['properties']['recalculated'] = "true"
        

print(response)
                
            
                
            
            #print(response['steps']['features'])
        #coordinates = [[11.653361, 52.144116], [11.62847, 52.1303]]
#coordinates = [[-76.96862697601318, -12.1659603049577], [-76.99416160583495, -12.1957651872979]]
#route_request = {'coordinates': coordinates, 
#                    'format_out': 'geojson',
#                    'profile': 'driving-car',
#                    'preference': 'shortest',
#                    'instructions': False
#                }

#'options': {'avoid_polygons': geometry.mapping(MultiPolygon(avoided_point_list))}} 
#route_directions = ors_client.directions(**route_request)
#route_directions
# Out:
# 1 has bad route
# 2 has bad route
# {'steps': {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'type': 'start', 'job': 99999, 'vehicle': 0}, 'geometry': {'type': 'Point', 'coordinates': [-77.01355, -12.195997]}}, {'type': 'Feature', 'properties': {'type': 'job', 'job': 2, 'vehicle': 0}, 'geometry': {'type': 'Point', 'coordinates': [-76.98832511901854, -12.164030528025286]}}, {'type': 'Feature', 'properties': {'type': 'job', 'job': 3, 'vehicle': 0}, 'geometry': {'type': 'Point', 'coordinates': [-76.99347496032716, -12.162436353905024]}}, {'type': 'Feature', 'properties': {'type': 'job', 'job': 0, 'vehicle': 0}, 'geometry': {'type': 'Point', 'coordinates': [-77.01355934143065, -12.195995894651212]}}, {'type': 'Feature', 'properties': {'type': 'end', 'job': -1, 'vehicle': 0}, 'geometry': {'type': 'Point', 'coordinates': [-77.01355, -12.195997]}}, {'type': 'Feature', 'properties': {'type': 'start', 'job': 99999, 'vehicle': 1}, 'geometry': {'type': 'Point', 'coordinates': [-77.01355, -12.195997]}}, {'type': 'Feature', 'properties': {'type': 'job', 'job': 8, 'vehicle': 1}, 'geometry': {'type': 'Point', 'coordinates': [-76.97227478027344, -12.138690418934832]}}, {'type': 'Feature', 'properties': {'type': 'job', 'job': 7, 'vehicle': 1}, 'geometry': {'type': 'Point', 'coordinates': [-76.96523666381835, -12.158157207685294]}}, {'type': 'Feature', 'properties': {'type': 'job', 'job': 6, 'vehicle': 1}, 'geometry': {'type': 'Point', 'coordinates': [-76.97133064270021, -12.167722262962966]}}, {'type': 'Feature', 'properties': {'type': 'end', 'job': -1, 'vehicle': 1}, 'geometry': {'type': 'Point', 'coordinates': [-77.01355, -12.195997]}}, {'type': 'Feature', 'properties': {'type': 'start', 'job': 99999, 'vehicle': 2}, 'geometry': {'type': 'Point', 'coordinates': [-77.01355, -12.195997]}}, {'type': 'Feature', 'properties': {'type': 'job', 'job': 4, 'vehicle': 2}, 'geometry': {'type': 'Point', 'coordinates': [-76.97802543640138, -12.192304552907098]}}, {'type': 'Feature', 'properties': {'type': 'job', 'job': 5, 'vehicle': 2}, 'geometry': {'type': 'Point', 'coordinates': [-76.98266029357909, -12.1997710773601]}}, {'type': 'Feature', 'properties': {'type': 'job', 'job': 1, 'vehicle': 2}, 'geometry': {'type': 'Point', 'coordinates': [-76.99776649475099, -12.191297814421771]}}, {'type': 'Feature', 'properties': {'type': 'end', 'job': -1, 'vehicle': 2}, 'geometry': {'type': 'Point', 'coordinates': [-77.01355, -12.195997]}}]}, 'routes': {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'distance': 12361, 'duration': 1473, 'vehicle': 0, 'recalculated': 'false'}, 'geometry': {'type': 'LineString', 'coordinates': [[-77.01364, -12.19614], [-77.01337, -12.1963], [-77.01247, -12.19684], [-77.01187, -12.19601], [-77.01181, -12.19598], [-77.01086, -12.19654], [-77.01096, -12.19668], [-77.01085, -12.19676], [-77.01075, -12.19662], [-77.01065, -12.19648], [-77.01055, -12.19634], [-77.01032, -12.19603], [-77.0102, -12.19575], [-77.00972, -12.19504], [-77.0097, -12.195], [-77.00902, -12.19407], [-77.00897, -12.194], [-77.00814, -12.19284], [-77.0081, -12.19278], [-77.00805, -12.19272], [-77.00705, -12.19135], [-77.00665, -12.19077], [-77.00636, -12.19036], [-77.00632, -12.1903], [-77.00623, -12.19019], [-77.00628, -12.19014], [-77.00653, -12.1899], [-77.00682, -12.1896], [-77.00687, -12.18955], [-77.00706, -12.18934], [-77.00724, -12.18913], [-77.00736, -12.18896], [-77.00747, -12.18876], [-77.0076, -12.18848], [-77.00767, -12.18818], [-77.00768, -12.18795], [-77.0077, -12.18765], [-77.00768, -12.18689], [-77.00768, -12.18671], [-77.00766, -12.18648], [-77.00765, -12.18639], [-77.00761, -12.18615], [-77.0076, -12.18609], [-77.00755, -12.18542], [-77.00753, -12.18518], [-77.00752, -12.18511], [-77.00751, -12.18504], [-77.00749, -12.18501], [-77.00747, -12.18497], [-77.00741, -12.18491], [-77.00736, -12.18488], [-77.00725, -12.18489], [-77.00709, -12.18488], [-77.00603, -12.18465], [-77.00468, -12.1844], [-77.00407, -12.18429], [-77.00369, -1 ...

# %%
def col_map(x):
    if x['properties']['vehicle'] == 0:
        color = "blue"
    elif x['properties']['vehicle'] == 1:
        color = "red"
    elif x['properties']['vehicle'] == 2:
        color = "purple"
    else:
        color = "black"
        
    
    return {
        "color": color
    }


m = folium.Map(location=depot, tiles='OpenStreetMap', zoom_start=12) 

i2 = folium.features.GeoJson(open(incidents_json).read(),  style_function=lambda x: {"fillColor": 'black'})
i3 = folium.features.GeoJson(response['steps'] )
i1 = folium.features.GeoJson(response['routes'], style_function=col_map)

i1.add_to(m)
i2.add_to(m)
i3.add_to(m)


 

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Make a map!

# First define the map centered around Beira
m = folium.Map(location=depot, tiles='OpenStreetMap', zoom_start=12)    


# Plot the locations on the map with more info in the ToolTip
for location in deliveries_data.itertuples():
    #tooltip = folium.map.Tooltip("<h4><b>ID {}</b></p><p>Supplies needed: <b>{}</b></p>".format(
    #    location.Index, location.Needed_Amount
    #))
    
    folium.Marker(
        location=[location.lat, location.lon],
        #tooltip=tooltip,
        icon=BeautifyIcon(
            icon_shape='marker',
            #number=int(location.index),
            spin=True,
            text_color='red',
            background_color="#FFF",
            inner_icon_style="font-size:12px;padding-top:-5px;"
        )
    #)
    ).add_to(m)    
    
# The vehicles are all located at the port of Beira
#depot = [-19.818474, 34.835447]

folium.Marker(
    location=depot,
    icon=BeautifyIcon(
            icon_shape='marker',
            #number=int(location.index),
            spin=True,
            text_color='green',
            background_color="pink",
            inner_icon_style="font-size:12px;padding-top:-5px;"
        ),
    setZIndexOffset=1000
).add_to(m)


# Add the output to the map
for color, route in zip(['green', 'red', 'blue'], opt_result['routes']):
    
    #decoded=ors.convert.decode_polyline(route['geometry'])  # Route geometry is encoded
    #print(decoded)
    
       
    gj = folium.GeoJson(
        name='Vehicle {}'.format(route['vehicle']),
        data={"type": "FeatureCollection", "features": [{"type": "Feature", 
                                                         "geometry": route['geometry'],
                                                         "properties": {"color": color}
                                                        }]},
        style_function=lambda x: {"color": x['properties']['color']}
    )
    gj.add_child(folium.Tooltip(
        """<h4>Vehicle {vehicle}</h4>
        <b>Distance</b> {distance} m <br>
        <b>Duration</b> {duration} secs
        """.format(**route)
    ))

    gj.add_to(m)
    
i2 = folium.features.GeoJson(open(incidents_json).read())
i2.add_to(m)


folium.LayerControl().add_to(m)
m

# %%
# Visualize start and destination point on map
coordinates = [[-76.96862697601318 -12.1659603049577], [-76.99416160583495 -12.1957651872979]] # Central Station and Fire Department
for coord in coordinates:
    folium.map.Marker(list(reversed(coord))).add_to(map_tweet)

# Regular Route
avoided_point_list = [] # Create empty list with avoided tweets
route_directions = CreateRoute(avoided_point_list) # Create regular route with still empty avoided_point_list

folium.features.GeoJson(data=route_directions,
                        name='Regular Route',
                        style_function=style_function('#ff5050'),
                        overlay=True).add_to(map_tweet)
print('Generated regular route.')

# %%
result['routes'][0]['geometry'] = decoded=ors.convert.decode_polyline(result['routes'][0]['geometry'])
result['routes'][0]

# %%
# Check if flood affected tweet is located on route
try:
    for site_poly in flood_tweets:
        poly = Polygon(site_poly)
        if poly.within(dilated_route):
            avoided_point_list.append(poly)

            # Create new route and buffer
            route_directions = CreateRoute(avoided_point_list, 1)
            dilated_route = CreateBuffer(route_directions)

    folium.features.GeoJson(data=route_directions,
                            name='Alternative Route',
                            style_function=style_function('#006600'),
                            overlay=True).add_to(map_tweet)
    print('Generated alternative route, which avoids affected areas.')
except Exception: 
    print('Sorry, there is no route available between the requested destination because of too many blocked streets.')

# %% [raw]
# # Add the output to the map
# for :
#
#     decoded=ors.convert.decode_polyline(route['geometry'])  # Route geometry is encoded
#     #print(decoded)
#
#
#     gj = folium.GeoJson(
#         name='Vehicle {}'.format(route['vehicle']),
#         data={"type": "FeatureCollection", "features": [{"type": "Feature",
#                                                          "geometry": decoded,
#                                                          "properties": {"color": color}
#                                                         }]},
#         style_function=lambda x: {"color": x['properties']['color']}
#     )
#     gj.add_child(folium.Tooltip(
#         """<h4>Vehicle {vehicle}</h4>
#         <b>Distance</b> {distance} m <br>
#         <b>Duration</b> {duration} secs
#         """.format(**route)
#     ))
#
#     gj.add_to(m)
#
# folium.LayerControl().add_to(m)
# m

# %%
# Later
# Function to create buffer around requested route
def CreateBuffer(route_directions): 
    line_tup = []
    for line in route_directions['features'][0]['geometry']['coordinates']:
        tup_format = tuple(line)
        line_tup.append(tup_format)  

    new_linestring = LineString(line_tup)
    dilated_route = new_linestring.buffer(0.001)
        
    return dilated_route
